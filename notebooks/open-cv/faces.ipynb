# %%
# %load_ext autoreload
# %autoreload 2
import sys,os
sys.path.append("/projects/computer-vision/")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import utils.cv_utils as cvu
import cv2 as cv
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# Out:
# WARNING: CPU random generator seem to be failing, disabling hardware random number generation
# WARNING: RDRND generated: 0xffffffff 0xffffffff 0xffffffff 0xffffffff

# %%
img = cv.imread("../opencv-course/Resources/Photos/lady.jpg")

# %%
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %%
cvu.cv_imshow("Gray Person", gray)

# %%
haar_cascade = cv.CascadeClassifier(f'{cv.data.haarcascades}haarcascade_frontalface_default.xml')

# %%
faces_rectangle = haar_cascade.detectMultiScale(image=gray, scaleFactor=1.1, minNeighbors=3)

# %%
print(f"{len(faces_rectangle)} found in this image")
# Out:
# 1 found in this image

# %%
for (x, y, w, h) in faces_rectangle:
    cv.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), thickness=2)

# %%
cvu.cv_imshow("Gray Person", img)

# %%
img = cv.imread("../opencv-course/Resources/Photos/group 1.jpg")
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
faces_rectangle = haar_cascade.detectMultiScale(image=gray, scaleFactor=1.1, minNeighbors=1)
print(f"{len(faces_rectangle)} found in this image")
for (x, y, w, h) in faces_rectangle:
    cv.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), thickness=2)
cvu.cv_imshow("Gray Person", img)
# Out:
# 19 found in this image

# %%
img = cv.imread("../opencv-course/Resources/Photos/group 2.jpg")
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
faces_rectangle = haar_cascade.detectMultiScale(image=gray, scaleFactor=1.1, minNeighbors=6)
print(f"{len(faces_rectangle)} found in this image")
for (x, y, w, h) in faces_rectangle:
    cv.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), thickness=2)
cvu.cv_imshow("Gray Person", img)
# Out:
# 6 found in this image

# %%
cv.imshow("Gray person", img)
cv.waitKey(0)
# Out:
# 0

# %%
# Haar cascade are very sensitive to noise (for overshoot and undershoot)
